# %% [markdown]
# # CDC_Capstone:  Part I - Getting to Know the Data

# %% [markdown]
# Purpose: This is a mutli-class classification problem used to determine the probability of diabetes based select features

# %%
#pip install import-ipynb

# %%
#pip install scipy

# %%
#### Run imports:
# standard data science imports
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Statistics imports
from scipy import stats
#import statsmodels.api as sm

import csv
import import_ipynb
import pandas as pd
#see more columns in my dataframe
pd.set_option('display.max_columns',100)

# %% [markdown]
# ## Reading in the data into a pandas DataFrame

# %%
#save functions and data source
# %run my_functions.ipynb

# %%
#read data
df = download_data(1)

# %%
df.head()
# Out:
#    ID  Diabetes_binary  HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 0   0                0       1         1          1   40       1       0
# 1   1                0       0         0          0   25       1       0
# 2   2                0       1         1          1   28       0       0
# 3   3                0       1         0          1   27       0       0
# 4   4                0       1         1          1   24       0       0
#
#    HeartDiseaseorAttack  PhysActivity  Fruits  Veggies  HvyAlcoholConsump  \
# 0                     0             0       0        1                  0
# 1                     0             1       0        0                  0
# 2                     0             0       1        0                  0
# 3                     0             1       1        1                  0
# 4                     0             1       1        1                  0
#
#    AnyHealthcare  NoDocbcCost  GenHlth  MentHlth  PhysHlth  DiffWalk  Sex  \
# ...

# %% [markdown]
# # Explore the Data

# %% [markdown]
# Use this space to familiarize myself with the data set.
#
#
#
# Do some quick EDA
# Check data types
# Check amount of data
# Look at summary statistics
# Review the column names

# %%
df.columns
# Out:
# Index(['ID', 'Diabetes_binary', 'HighBP', 'HighChol', 'CholCheck', 'BMI',
#        'Smoker', 'Stroke', 'HeartDiseaseorAttack', 'PhysActivity', 'Fruits',
#        'Veggies', 'HvyAlcoholConsump', 'AnyHealthcare', 'NoDocbcCost',
#        'GenHlth', 'MentHlth', 'PhysHlth', 'DiffWalk', 'Sex', 'Age',
#        'Education', 'Income'],
#       dtype='object')

# %% [markdown]
# Imports

# %%
#display number of rows and columns
df.shape
# Out:
# (253680, 23)

# %%
#display info
df.describe
# Out:
# <bound method NDFrame.describe of             ID  Diabetes_binary  HighBP  HighChol  CholCheck  BMI  Smoker  \
# 0            0                0       1         1          1   40       1
# 1            1                0       0         0          0   25       1
# 2            2                0       1         1          1   28       0
# 3            3                0       1         0          1   27       0
# 4            4                0       1         1          1   24       0
# ...        ...              ...     ...       ...        ...  ...     ...
# 253675  253675                0       1         1          1   45       0
# 253676  253676                1       1         1          1   18       0
# 253677  253677                0       0         0          1   28       0
# 253678  253678                0       1         0          1   23       0
# 253679  253679                1       1         1          1   25       0
#
# ...

# %%
df.dtypes
# Out:
# ID                      int64
# Diabetes_binary         int64
# HighBP                  int64
# HighChol                int64
# CholCheck               int64
# BMI                     int64
# Smoker                  int64
# Stroke                  int64
# HeartDiseaseorAttack    int64
# PhysActivity            int64
# Fruits                  int64
# Veggies                 int64
# HvyAlcoholConsump       int64
# AnyHealthcare           int64
# NoDocbcCost             int64
# GenHlth                 int64
# MentHlth                int64
# PhysHlth                int64
# DiffWalk                int64
# Sex                     int64
# Age                     int64
# Education               int64
# Income                  int64
# dtype: object

# %%
#discovering more info about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253680 entries, 0 to 253679
# Data columns (total 23 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    253680 non-null  int64
#  1   Diabetes_binary       253680 non-null  int64
#  2   HighBP                253680 non-null  int64
#  3   HighChol              253680 non-null  int64
#  4   CholCheck             253680 non-null  int64
#  5   BMI                   253680 non-null  int64
#  6   Smoker                253680 non-null  int64
#  7   Stroke                253680 non-null  int64
#  8   HeartDiseaseorAttack  253680 non-null  int64
#  9   PhysActivity          253680 non-null  int64
#  10  Fruits                253680 non-null  int64
#  11  Veggies               253680 non-null  int64
#  12  HvyAlcoholConsump     253680 non-null  int64
#  13  AnyHealthcare         253680 non-null  int64
# ...

# %%
#identify missing values -- the data has no missing values
df.isna().sum()
# Out:
# ID                      0
# Diabetes_binary         0
# HighBP                  0
# HighChol                0
# CholCheck               0
# BMI                     0
# Smoker                  0
# Stroke                  0
# HeartDiseaseorAttack    0
# PhysActivity            0
# Fruits                  0
# Veggies                 0
# HvyAlcoholConsump       0
# AnyHealthcare           0
# NoDocbcCost             0
# GenHlth                 0
# MentHlth                0
# PhysHlth                0
# DiffWalk                0
# Sex                     0
# Age                     0
# Education               0
# Income                  0
# dtype: int64

# %% [markdown]
# Dataset has no missing values

# %%
#counter where value is True
is_Smoker = df['Smoker'] == 1

# %%
is_Smoker.describe()
# Out:
# count     253680
# unique         2
# top        False
# freq      141257
# Name: Smoker, dtype: object

# %%
df.head(1)
# Out:
#    ID  Diabetes_binary  HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 0   0                0       1         1          1   40       1       0
#
#    HeartDiseaseorAttack  PhysActivity  Fruits  Veggies  HvyAlcoholConsump  \
# 0                     0             0       0        1                  0
#
#    AnyHealthcare  NoDocbcCost  GenHlth  MentHlth  PhysHlth  DiffWalk  Sex  \
# 0              1            0        5        18        15         1    0
#
#    Age  Education  Income
# 0    9          4       3

# %%
#Obervation
# 0 - Male
# 1- Female

df.groupby(by = ['Sex','Smoker']).count()[['Diabetes_binary']]
# Out:
#             Diabetes_binary
# Sex Smoker
# 0   0                 84915
#     1                 57059
# 1   0                 56342
#     1                 55364

# %%
 
sns.countplot(x='Diabetes_binary',hue='Sex',data=df)
plt.title('Gender vs Diabetes', fontsize=14)
#plt.xticks(rotation=45)
#plt.legend()
plt.show()

# %%
#Obervation Smokers
# 0 - Non Smoker
# 1- Smoker
 
sns.countplot(x='Diabetes_binary',hue='Smoker',data=df)
plt.title('Diabetes vs Smoker', fontsize=14)
#plt.xticks(rotation=45)
#plt.legend()
plt.show()

# %% [markdown]
# Observed non smoker both men and women have less number of cases of diabetes

# %%
#PhysHlth  DiffWalk  Sex  Age  Education  Income  
#1 Never attended school or only kindergarten  
#2 Grades 1 through 8 (Elementary)   
#3 Grades 9 through 11 (Some high school)   
#4 Grade 12 or GED (High school graduate)   
#5 College 1 year to 3 years (Some college or technical school)   
#6 College 4 years or more (College graduate)   
#9 Refused   
#BLANK Not asked or Missing 1,770

df['Education'].value_counts()
# Out:
# 6    107325
# 5     69910
# 4     62750
# 3      9478
# 2      4043
# 1       174
# Name: Education, dtype: int64

# %%
#graph Education vs Diabetes 
sns.countplot(x='Diabetes_binary',hue='Education',data=df)
plt.title('Diabetes vs Education', fontsize=14)
#plt.xticks(rotation=45)
#plt.legend()
plt.show()

# %% [markdown]
# Educated individuals are more likely to not have diabetes

# %%
#Obervation
# 0 - Male
# 1- Female

df.groupby(by = ['Sex','HeartDiseaseorAttack']).count()[['Diabetes_binary']]
# Out:
#                           Diabetes_binary
# Sex HeartDiseaseorAttack
# 0   0                              131769
#     1                               10205
# 1   0                               98018
#     1                               13688

# %%
#graph HeartDisease or Attack vs Diabetes 
sns.countplot(x='Diabetes_binary',hue='HeartDiseaseorAttack',data=df)
plt.title('Diabetes vs Heart Disease or Attack', fontsize=14)
#plt.xticks(rotation=45)
#plt.legend()
plt.show()

# %% [markdown]
# Graph shows heart disease does not have a direct impact on diabetis

# %% [markdown]
# ### create subsets of data for charts later

# %%
# Choose a random sample of 2 rows
sample_df = pd.DataFrame(df.sample(n=500),columns = df.columns)

# %%
print(type(sample_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#create a dictionary. Save all my dataframes to my dictionary
data_dic = {}

# %%
#create a subset of data
data_dic['menhealth_data'] = sample_df[['Diabetes_binary', 'MentHlth','Sex' ]]

# %%
#create a subset of data
data_dic['genhealth_data'] = sample_df[['Diabetes_binary', 'GenHlth','Sex' ]]

# %%
#create a subset of data
data_dic['physical_data'] = sample_df[['Diabetes_binary', 'PhysActivity', 'Sex' ]]

# %%
data_dic['dietary_data'] = sample_df[['Diabetes_binary', 'Fruits','Veggies','Sex']]

# %%
data_dic['heart_data'] = sample_df[['Diabetes_binary','HeartDiseaseorAttack' , 'Sex' ]]

# %%
data_dic['sex_data'] = sample_df[['Diabetes_binary', 'Sex']]

# %%
data_dic['edu_data'] = sample_df[['Diabetes_binary', 'Education']]

# %%
#save these dataframes to my data/raw folder on my local drive 
write_data(data_dic,'data/raw',index=False)

# %% [markdown]
# individual that eat fruits and veggies with physical activity had less diabetes

# %% [markdown]
# Individuals that stay active are less likely to have heart attack or diabetes

# %% [markdown]
# ### summary statistics

# %%
 
def summary_statistics(column, data):
    X = data[column]
    print ('COLUMN: ' + column)
    print ('mean: ' + str(np.mean(X)))
    print ('median: ' + str(np.median(X)))
    print ('mode: ' + str(stats.mode([round(d) for d in X])))
    print ('variance: ' + str(np.var(X)))
    print ('standard deviation: ' + str(np.std(X)))

# %%
#Identify a normal distribution within a data set using summary statistics and data visualizations
summary_statistics('Age', df)
# Out:
# COLUMN: Age
# mean: 8.032119205298013
# median: 8.0
# mode: ModeResult(mode=9, count=33244)
# variance: 9.328225688722927
# standard deviation: 3.054214414333566

# %% [markdown]
# Average age is 8

# %% [markdown]
# ### Education levels

# %% [markdown]
# #1 Never attended school or only kindergarten
# #2 Grades 1 through 8 (Elementary)
# #3 Grades 9 through 11 (Some high school)
# #4 Grade 12 or GED (High school graduate)
# #5 College 1 year to 3 years (Some college or technical school)
# #6 College 4 years or more (College graduate)
# #9 Refused
# #BLANK Not asked or Missing 1,770

# %%
#Identify a normal distribution within a data set using summary statistics and data visualizations
summary_statistics('Education', df)
# Out:
# COLUMN: Education
# mean: 5.050433617155472
# median: 5.0
# mode: ModeResult(mode=6, count=107325)
# variance: 0.9717468949152983
# standard deviation: 0.9857722327775815

# %% [markdown]
# Average education is College 1 year to 3 years

# %%
df[['Diabetes_binary', 'Education','Age','PhysActivity','Fruits','Veggies' ]].describe()
# Out:
#        Diabetes_binary      Education            Age   PhysActivity  \
# count    253680.000000  253680.000000  253680.000000  253680.000000
# mean          0.139333       5.050434       8.032119       0.756544
# std           0.346294       0.985774       3.054220       0.429169
# min           0.000000       1.000000       1.000000       0.000000
# 25%           0.000000       4.000000       6.000000       1.000000
# 50%           0.000000       5.000000       8.000000       1.000000
# 75%           0.000000       6.000000      10.000000       1.000000
# max           1.000000       6.000000      13.000000       1.000000
#
#               Fruits        Veggies
# count  253680.000000  253680.000000
# mean        0.634256       0.811420
# std         0.481639       0.391175
# min         0.000000       0.000000
# 25%         0.000000       1.000000
# 50%         1.000000       1.000000
# 75%         1.000000       1.000000
# max         1.000000       1.000000

# %% [markdown]
# Education average in the data is college 1-3 years experience

# %% [markdown]
# # Correlation

# %% [markdown]
# ## Identify most prominent features

# %%
corr = df.corr()
# Heatmap for data correaltion
f, ax = plt.subplots(figsize=(11,9))
sns.heatmap(corr, annot=True)
#sns.heatmap(corr)
# Out:
# <Axes: >

# %% [markdown]
# identified heat around diffwalk, physical health, general health income and eduction.

# %%
#Take a closer look
corr = df[['Education','Diabetes_binary','HighBP','HighChol','CholCheck','GenHlth','MentHlth','PhysHlth','DiffWalk','Sex','Age','Income']].corr()
# Heatmap for data correaltion
f, ax = plt.subplots(figsize=(11,9))
sns.heatmap(corr, annot=True)
#sns.heatmap(corr)
# Out:
# <Axes: >

# %% [markdown]
# Top 5 correlated features are centered around mental and phyical health.  I plan to use this features when I build my prediction model

# %% [markdown]
# Convince yourself that there are no issues with the data. If you find any, clean them now.

# %%
#only show correlations where the values are greater than .3

#Let's create a heatmap only with significant corrrelations that is a bit easier to read.

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))
mask = mask|((np.abs(corr)<0.3).values)

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(20, 18))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
hm = sns.heatmap(corr, mask=mask, cmap=cmap, vmax=0.8, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

hm.set_title('Correlation Heatmap for Hwy Mpg Data', fontsize=20)
ax.set_xticklabels(ax.get_xmajorticklabels(), fontsize=12)
ax.set_yticklabels(ax.get_ymajorticklabels(), fontsize=12)
plt.xticks(rotation=30, ha='right')
plt.yticks(rotation=30, ha='right')

plt.show();
