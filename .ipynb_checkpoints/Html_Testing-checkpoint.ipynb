# %%
# %%html --isolated
# <style>
#     p{
#         color:red;
#         font-size:25px;
#         font-weight:750;
#         background-color:tan;
#     }
# </style>
# <h3>Forecasting Diabetes Dashboard</h3>
# <p>Makes predictions for diabetes</p>
# Out:
# <style>
#     p{
#         color:red;
#         font-size:25px;
#         font-weight:750;
#         background-color:tan;
#     }
# </style>
# <h3>Forecasting Diabetes Dashboard</h3>
# <p>Makes predictions for diabetes</p>

# %%
# %%html --isolated
# <style>
#     h2 {
#         border: 2px dashed blue;
#
#     }
#     p{
#         color: darkgreen;
#         font-size:25px;
#         font-weight:750;
#         background-color:tan;
#         text-align: center;
#         border: 2px dashed blue;
#
#     }
# </style>
# <h2>Forecasting Diabetes Dashboard</h2>
# <p>Makes predictions for diabetes</p>
# <h2>Another header</h2>
# Out:
# <style>
#     h2 {
#         border: 2px dashed blue;
#
#     }
#     p{
#         color: darkgreen;
#         font-size:25px;
#         font-weight:750;
#         background-color:tan;
#         text-align: center;
#         border: 2px dashed blue;
#
#     }
# </style>
# <h2>Forecasting Diabetes Dashboard</h2>
# <p>Makes predictions for diabetes</p>
# <h2>Another header</h2>

# %%
# %%html --isolated
# <style>
#     h2 {
#         border: 2px dashed blue;
#
#     }
#     p{
#         color: darkgreen;
#         font-size:25px;
#         font-weight:750;
#         background-color:tan;
#         text-align: center;
#         border: 2px dashed blue;
#         display: inline;
#     }
# </style>
# <h2>Forecasting Diabetes Dashboard</h2>
# <p>Makes predictions for diabetes</p>
# <h2>Another header</h2>
# Out:
# <style>
#     h2 {
#         border: 2px dashed blue;
#
#     }
#     p{
#         color: darkgreen;
#         font-size:25px;
#         font-weight:750;
#         background-color:tan;
#         text-align: center;
#         border: 2px dashed blue;
#         display: inline;
#     }
# </style>
# <h2>Forecasting Diabetes Dashboard</h2>
# <p>Makes predictions for diabetes</p>
# <h2>Another header</h2>

# %%
# %%html --isolated
# <style>
#     h2 {
#         border: 2px dashed blue;
#         display: inline;
#     }
#     p{
#         color: darkgreen;
#         font-size:25px;
#         font-weight:750;
#         background-color:tan;
#         text-align: center;
#         border: 2px dashed blue;
#         display: inline;
#     }
# </style>
# <h2>Forecasting Diabetes Dashboard</h2>
# <p>Makes predictions for diabetes</p>
# <h2>Another header</h2>
# Out:
# <style>
#     h2 {
#         border: 2px dashed blue;
#         display: inline;
#     }
#     p{
#         color: darkgreen;
#         font-size:25px;
#         font-weight:750;
#         background-color:tan;
#         text-align: center;
#         border: 2px dashed blue;
#         display: inline;
#     }
# </style>
# <h2>Forecasting Diabetes Dashboard</h2>
# <p>Makes predictions for diabetes</p>
# <h2>Another header</h2>

# %%
import dash
from jupyter_dash import JupyterDash
from dash import dcc, html, Input, Output
import dash_html_components as html
import dash_bootstrap_components as dbc
from PIL import Image

# %%
banner_img = Image.open("assets/banner2.PNG")

link = html.A('View Github Repository', href="https://github.com/yourexodus/capstone_CDC")
 

banner_item = html.Div(
    [
        html.Div(
            html.Div(
                [
                    html.Div([
                       # html.Img(src=banner_img, style={'width': '100%', 'height': '50%'})
                        html.Img(src=banner_img, style={'width': '100%', 'height': '200px'})
                       # html.Img(src=banner_img, 'width': '50%', 'height': '200px'),               # using the pillow image variable
                        
                    ]),
                    html.Div(className="sidebar-wrapper"),
                ]
            ),
            className="sidebar",
        ),
        html.Div(
            html.Div(
                html.Div(className="container-fluid"),
                className="navbar navbar-expand-lg navbar-transparent navbar-absolute fixed-top ",
            ),
            className="main-panel",
        ),
    ]
)
banner_item.style = {'gridArea': "banner_item"}


layout = html.Div([link, banner_item])



app = dash.Dash(__name__)  # Initialize Dash app
app.layout = layout        #set layout
#app.run_server(mode='inline', height=100)  # Run the server
app.run_server(mode='inline', height=100, port=8054)  # Change the port number (e.g., 8051)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8054/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
doctorcat_img = Image.open("assets/doctorcat.PNG")

link = html.A('View Github Repository', href="https://github.com/yourexodus/capstone_CDC")
 

doctorcat_item = html.Div(
    [
        html.Div(
            html.Div(
                [
                    html.Div([
                       # html.Img(src=banner_img, style={'width': '100%', 'height': '50%'})
                        html.Img(src=doctorcat_img, style={'width': '200px', 'height': '200px'})
                       # html.Img(src=banner_img, 'width': '50%', 'height': '200px'),               # using the pillow image variable
                        
                    ]),
                    html.Div(className="sidebar-wrapper"),
                ]
            ),
            className="sidebar",
        ),
        html.Div(
            html.Div(
                html.Div(className="container-fluid"),
                className="navbar navbar-expand-lg navbar-transparent navbar-absolute fixed-top ",
            ),
            className="main-panel",
        ),
    ]
)
doctorcat_item.style = {'gridArea': "doctorcat_item"}


layout = html.Div([link, doctorcat_item])



app = dash.Dash(__name__)  # Initialize Dash app
app.layout = layout        #set layout
#app.run_server(mode='inline', height=100)  # Run the server
app.run_server(mode='inline', height=100, port=8054)  # Change the port number (e.g., 8051)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8054/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import dash
from dash import dcc, html

app = dash.Dash(__name__)

options = [
    {'label': 'New York City', 'value': 'NYC'},
    {'label': 'Montreal', 'value': 'MTL'},
    {'label': 'San Francisco', 'value': 'SF'}
]
menu_income:[
    {'label':'1 - Less than $10,000', 'value':1}, 
    {'label':'2 - Less than $15,000 ($10,000 to less than $15,000)', 'value':2},
    {'label':'3 - Less than $20,000 ($15,000 to less than $20,000)', 'value':3},
    {'label':'4 - Less than $25,000 ($20,000 to less than $25,000)', 'value':4},
    {'label':'5 - Less than $35,000 ($25,000 to less than $35,000)', 'value':5},
    {'label':'6 - Less than $50,000 ($35,000 to less than $50,000)', 'value':6},
    {'label':'7 - Less than $75,000 ($50,000 to less than $75,000)', 'value':7},
    {'label':'8 - $75,000 or more', 'value':8}
    ]

table_item = html.Div(
    id="my-table",  # Add the ID here
    children=[
        html.Table([
            html.Thead([
                html.Tr([
                    html.Th("Column 1"),
                    html.Th("Column 2"),
                    html.Th("Column 3")
                ])
            ]),
            html.Tbody([
                html.Tr([
                    html.Tr([  # Each row goes here
                        html.Tr([  # Each row goes here
                            html.Td("Row 1, Column 1"),  # Use Td for table data
                            html.Td("Row 1, Column 2") 
                             
                        ]),
                        # Add more rows here
                        html.Tr([  # Each row goes here
                            html.Td("Row 2, Column 1"),  # Use Td for table data
                            html.Td("Row 2, Column 2") 
                             
                        ]),
                        html.Tr([  # Each row goes here
                            html.Td("Row 3, Column 1"),  # Use Td for table data
                            html.Td("Row 3, Column 2") 
                        ])   
                    ])
                ])
                    
            ])
        ])
    ]
)


user_input =    html.Div([
        dcc.Dropdown(
            id='menu_income',
            options=options,
            placeholder="Please choose your income range."
            #value='NYC1'  # Initial value
        ),
        dcc.Dropdown(
            id='my-dropdown2',
            options=options,
            placeholder="Select a city"
            #value='NYC2'  # Initial value
        ),
        dcc.Dropdown(
            id='my-dropdown3',
            options=options,
            placeholder="Select a city"
            #value='NYC3'  # Initial value
        )        
        
    ])

#layout = html.Div([title, user_input,  summary_table])

layout = html.Div([link, banner_item, table_item , user_input])



app = dash.Dash(__name__)  # Initialize Dash app
app.layout = layout        #set layout
#app.run_server(mode='inline', height=100)  # Run the server
app.run_server(mode='inline', height=100, port=8054)  # Change the port number (e.g., 8051)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8054/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import dash
from dash import dcc, html

app = dash.Dash(__name__)

options = [
    {'label': 'New York City', 'value': 'NYC'},
    {'label': 'Montreal', 'value': 'MTL'},
    {'label': 'San Francisco', 'value': 'SF'}
]
menu_income:[
    {'label':'1 - Less than $10,000', 'value':1}, 
    {'label':'2 - Less than $15,000 ($10,000 to less than $15,000)', 'value':2},
    {'label':'3 - Less than $20,000 ($15,000 to less than $20,000)', 'value':3},
    {'label':'4 - Less than $25,000 ($20,000 to less than $25,000)', 'value':4},
    {'label':'5 - Less than $35,000 ($25,000 to less than $35,000)', 'value':5},
    {'label':'6 - Less than $50,000 ($35,000 to less than $50,000)', 'value':6},
    {'label':'7 - Less than $75,000 ($50,000 to less than $75,000)', 'value':7},
    {'label':'8 - $75,000 or more', 'value':8}
    ]

table_cell_container = html.Div(
    children=[
        doctorcat_item  # Existing doctorcat_item structure
    ],
    style={
        "display": "grid",  # Enable grid layout
        "grid-template-columns": "1fr",  # Single column layout
        "grid-template-rows": "auto",  # Flexible row sizing
        "width": "100%",  # Optional: Set cell width
        "height": "200px",  # Optional: Set cell height
    },
)


table_item = html.Div(
    id="my-table",  # Add the ID here
    children=[
        html.Table(
            style={'width': '100%'},  # Optional: Set table width
            children=[
                html.Thead([
                    html.Tr([
                        html.Th("Labatory Technician"),
                        html.Th("Diabetes"),
                        html.Th("Questionaire"),
                    ])
                ]),
                html.Tbody([
                    html.Tr([
                        html.Td(
                            children=[
                                html.Div(
                                    children=[table_cell_container],
                                    style={
                                         "display": "flex",
                                        "justify-content": "center",
                                        "align-items": "center",
                                        "width": "400px",  # Adjust width as needed
                                        "height": "250px",  # Adjust height as needed
                                            },
                                )
                            
                               # "Row 1, Column 1",
                               # style={'vertical-align': 'top', 'rowspan': 2},  # Style for spanning  HERE HERE HERE 
                            ]
                            ),
                        html.Td("Row 1, Column 2"),
                        html.Td("Row 1, Column 3"),
                    ]),
                    html.Tr([
                        html.Td(),  # Empty cell for visual effect
                        html.Td("Row 2, Column 2"),
                        html.Td("Row 2, Column 3"),
                    ]),
                ]),
            ],
        )
    ],
)

user_input =    html.Div([
        dcc.Dropdown(
            id='menu_income',
            options=options,
            placeholder="Please choose your income range."
            #value='NYC1'  # Initial value
        ),
        dcc.Dropdown(
            id='my-dropdown2',
            options=options,
            placeholder="Select a city"
            #value='NYC2'  # Initial value
        ),
        dcc.Dropdown(
            id='my-dropdown3',
            options=options,
            placeholder="Select a city"
            #value='NYC3'  # Initial value
        )        
        
    ])

#layout = html.Div([title, user_input,  summary_table])

layout = html.Div([link, banner_item, table_item , user_input])



app = dash.Dash(__name__)  # Initialize Dash app
app.layout = layout        #set layout
#app.run_server(mode='inline', height=100)  # Run the server
app.run_server(mode='inline', height=100, port=8054)  # Change the port number (e.g., 8051)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8054/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#COPYT

# %%
import dash
from dash import dcc, html

app = dash.Dash(__name__)

options = [
    {'label': 'New York City', 'value': 'NYC'},
    {'label': 'Montreal', 'value': 'MTL'},
    {'label': 'San Francisco', 'value': 'SF'}
]
menu_income:[
    {'label':'1 - Less than $10,000', 'value':1}, 
    {'label':'2 - Less than $15,000 ($10,000 to less than $15,000)', 'value':2},
    {'label':'3 - Less than $20,000 ($15,000 to less than $20,000)', 'value':3},
    {'label':'4 - Less than $25,000 ($20,000 to less than $25,000)', 'value':4},
    {'label':'5 - Less than $35,000 ($25,000 to less than $35,000)', 'value':5},
    {'label':'6 - Less than $50,000 ($35,000 to less than $50,000)', 'value':6},
    {'label':'7 - Less than $75,000 ($50,000 to less than $75,000)', 'value':7},
    {'label':'8 - $75,000 or more', 'value':8}
    ]

table_item = html.Div(
    id="my-table",  # Add the ID here
    children=[
        html.Table(
            style={'width': '100%'},  # Optional: Set table width
            children=[
                html.Thead([
                    html.Tr([
                        html.Th("Column 1"),
                        html.Th("Column 2"),
                        html.Th("Column 3"),
                    ])
                ]),
                html.Tbody([
                    html.Tr([
                        html.Td(
                            children=[
                                html.Div(
                                    "Content inside a styled Td",
                                    style={
                                        "padding": "10px",
                                        "border": "1px solid lightgray",
                                        "background-color": "#f5f5f5",
                                    },
                                )
                            
                               # "Row 1, Column 1",
                               # style={'vertical-align': 'top', 'rowspan': 2},  # Style for spanning  HERE HERE HERE 
                            ]
                            ),
                        html.Td("Row 1, Column 2"),
                        html.Td("Row 1, Column 3"),
                    ]),
                    html.Tr([
                        html.Td(),  # Empty cell for visual effect
                        html.Td("Row 2, Column 2"),
                        html.Td("Row 2, Column 3"),
                    ]),
                ]),
            ],
        )
    ],
)

user_input =    html.Div([
        dcc.Dropdown(
            id='menu_income',
            options=options,
            placeholder="Please choose your income range."
            #value='NYC1'  # Initial value
        ),
        dcc.Dropdown(
            id='my-dropdown2',
            options=options,
            placeholder="Select a city"
            #value='NYC2'  # Initial value
        ),
        dcc.Dropdown(
            id='my-dropdown3',
            options=options,
            placeholder="Select a city"
            #value='NYC3'  # Initial value
        )        
        
    ])

#layout = html.Div([title, user_input,  summary_table])

layout = html.Div([link, banner_item, table_item , user_input])



app = dash.Dash(__name__)  # Initialize Dash app
app.layout = layout        #set layout
#app.run_server(mode='inline', height=100)  # Run the server
app.run_server(mode='inline', height=100, port=8054)  # Change the port number (e.g., 8051)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8054/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import dash
from dash import dcc, html

app = dash.Dash(__name__)

options = [
    {'label': 'New York City', 'value': 'NYC'},
    {'label': 'Montreal', 'value': 'MTL'},
    {'label': 'San Francisco', 'value': 'SF'}
]
menu_income:[
    {'label':'1 - Less than $10,000', 'value':1}, 
    {'label':'2 - Less than $15,000 ($10,000 to less than $15,000)', 'value':2},
    {'label':'3 - Less than $20,000 ($15,000 to less than $20,000)', 'value':3},
    {'label':'4 - Less than $25,000 ($20,000 to less than $25,000)', 'value':4},
    {'label':'5 - Less than $35,000 ($25,000 to less than $35,000)', 'value':5},
    {'label':'6 - Less than $50,000 ($35,000 to less than $50,000)', 'value':6},
    {'label':'7 - Less than $75,000 ($50,000 to less than $75,000)', 'value':7},
    {'label':'8 - $75,000 or more', 'value':8}
    ]

table_item = html.Div(
    id="my-table",  # Add the ID here
    children=[
        html.Table(
            style={'width': '100%'},  # Optional: Set table width
            children=[
                html.Thead([
                    html.Tr([
                        html.Th("Column 1"),
                        html.Th("Column 2"),
                        html.Th("Column 3"),
                    ])
                ]),
                html.Tbody([
                    html.Tr([
                        html.Td(
                            children=[
                                html.Div(
                                    "Content inside a styled Td",
                                    style={
                                        "padding": "10px",
                                        "border": "1px solid lightgray",
                                        "background-color": "#f5f5f5",
                                    },
                                )
                            
                               # "Row 1, Column 1",
                               # style={'vertical-align': 'top', 'rowspan': 2},  # Style for spanning  HERE HERE HERE 
                            ]
                            ),
                        html.Td("Row 1, Column 2"),
                        html.Td("Row 1, Column 3"),
                    ]),
                    html.Tr([
                        html.Td(),  # Empty cell for visual effect
                        html.Td("Row 2, Column 2"),
                        html.Td("Row 2, Column 3"),
                    ]),
                ]),
            ],
        )
    ],
)

user_input =    html.Div([
        dcc.Dropdown(
            id='menu_income',
            options=options,
            placeholder="Please choose your income range."
            #value='NYC1'  # Initial value
        ),
        dcc.Dropdown(
            id='my-dropdown2',
            options=options,
            placeholder="Select a city"
            #value='NYC2'  # Initial value
        ),
        dcc.Dropdown(
            id='my-dropdown3',
            options=options,
            placeholder="Select a city"
            #value='NYC3'  # Initial value
        )        
        
    ])

#layout = html.Div([title, user_input,  summary_table])

layout = html.Div([link, banner_item, table_item , user_input])



app = dash.Dash(__name__)  # Initialize Dash app
app.layout = layout        #set layout
#app.run_server(mode='inline', height=100)  # Run the server
app.run_server(mode='inline', height=100, port=8054)  # Change the port number (e.g., 8051)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8054/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import dash
from dash import dcc, html

app = dash.Dash(__name__)

options = [
    {'label': 'New York City', 'value': 'NYC'},
    {'label': 'Montreal', 'value': 'MTL'},
    {'label': 'San Francisco', 'value': 'SF'}
]
menu_income:[
    {'label':'1 - Less than $10,000', 'value':1}, 
    {'label':'2 - Less than $15,000 ($10,000 to less than $15,000)', 'value':2},
    {'label':'3 - Less than $20,000 ($15,000 to less than $20,000)', 'value':3},
    {'label':'4 - Less than $25,000 ($20,000 to less than $25,000)', 'value':4},
    {'label':'5 - Less than $35,000 ($25,000 to less than $35,000)', 'value':5},
    {'label':'6 - Less than $50,000 ($35,000 to less than $50,000)', 'value':6},
    {'label':'7 - Less than $75,000 ($50,000 to less than $75,000)', 'value':7},
    {'label':'8 - $75,000 or more', 'value':8}
    ]

table_item = html.Div(
    id="my-table",  # Add the ID here
    children=[
        html.Table(
            style={'width': '100%'},  # Optional: Set table width
            children=[
                html.Thead([
                    html.Tr([
                        html.Th("Column 1"),
                        html.Th("Column 2"),
                        html.Th("Column 3"),
                    ])
                ]),
                html.Tbody([
                    html.Tr([
                        html.Td(
                            "Row 1, Column 1",
                            style={'vertical-align': 'top', 'rowspan': 2},  # Style for spanning  HERE HERE HERE 
                        ),
                        html.Td("Row 1, Column 2"),
                        html.Td("Row 1, Column 3"),
                    ]),
                    html.Tr([
                        html.Td(),  # Empty cell for visual effect
                        html.Td("Row 2, Column 2"),
                        html.Td("Row 2, Column 3"),
                    ]),
                ]),
            ],
        )
    ],
)

user_input =    html.Div([
        dcc.Dropdown(
            id='menu_income',
            options=options,
            placeholder="Please choose your income range."
            #value='NYC1'  # Initial value
        ),
        dcc.Dropdown(
            id='my-dropdown2',
            options=options,
            placeholder="Select a city"
            #value='NYC2'  # Initial value
        ),
        dcc.Dropdown(
            id='my-dropdown3',
            options=options,
            placeholder="Select a city"
            #value='NYC3'  # Initial value
        )        
        
    ])

#layout = html.Div([title, user_input,  summary_table])

layout = html.Div([link, banner_item, table_item , user_input])



app = dash.Dash(__name__)  # Initialize Dash app
app.layout = layout        #set layout
#app.run_server(mode='inline', height=100)  # Run the server
app.run_server(mode='inline', height=100, port=8054)  # Change the port number (e.g., 8051)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8054/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import dash
from dash import dcc, html

app = dash.Dash(__name__)

options = [
    {'label': 'New York City', 'value': 'NYC'},
    {'label': 'Montreal', 'value': 'MTL'},
    {'label': 'San Francisco', 'value': 'SF'}
]
menu_income:[
    {'label':'1 - Less than $10,000', 'value':1}, 
    {'label':'2 - Less than $15,000 ($10,000 to less than $15,000)', 'value':2},
    {'label':'3 - Less than $20,000 ($15,000 to less than $20,000)', 'value':3},
    {'label':'4 - Less than $25,000 ($20,000 to less than $25,000)', 'value':4},
    {'label':'5 - Less than $35,000 ($25,000 to less than $35,000)', 'value':5},
    {'label':'6 - Less than $50,000 ($35,000 to less than $50,000)', 'value':6},
    {'label':'7 - Less than $75,000 ($50,000 to less than $75,000)', 'value':7},
    {'label':'8 - $75,000 or more', 'value':8}
    ]

table_item = html.Div(
    id="my-table",  # Add the ID here
    children=[
        html.Table(
            style={'width': '100%'},  # Optional: Set table width
            children=[
                html.Thead([
                    html.Tr([
                        html.Th("Column 1"),
                        html.Th("Column 2"),
                        html.Th("Column 3"),
                    ])
                ]),
                html.Tbody([
                    html.Tr([
                        html.Td(
                            "Row 1, Column 1",
                            style={'vertical-align': 'top', 'rowspan': 2},  # Style for spanning  HERE HERE HERE 
                        ),
                        html.Td("Row 1, Column 2"),
                        html.Td("Row 1, Column 3"),
                    ]),
                    html.Tr([
                        html.Td(),  # Empty cell for visual effect
                        html.Td("Row 2, Column 2"),
                        html.Td("Row 2, Column 3"),
                    ]),
                ]),
            ],
        )
    ],
)

user_input =    html.Div([
        dcc.Dropdown(
            id='menu_income',
            options=options,
            placeholder="Please choose your income range."
            #value='NYC1'  # Initial value
        ),
        dcc.Dropdown(
            id='my-dropdown2',
            options=options,
            placeholder="Select a city"
            #value='NYC2'  # Initial value
        ),
        dcc.Dropdown(
            id='my-dropdown3',
            options=options,
            placeholder="Select a city"
            #value='NYC3'  # Initial value
        )        
        
    ])

#layout = html.Div([title, user_input,  summary_table])

layout = html.Div([link, banner_item, table_item , user_input])



app = dash.Dash(__name__)  # Initialize Dash app
app.layout = layout        #set layout
#app.run_server(mode='inline', height=100)  # Run the server
app.run_server(mode='inline', height=100, port=8054)  # Change the port number (e.g., 8051)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8054/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import dash
from dash import dcc, html

app = dash.Dash(__name__)

options = [
    {'label': 'New York City', 'value': 'NYC'},
    {'label': 'Montreal', 'value': 'MTL'},
    {'label': 'San Francisco', 'value': 'SF'}
]
menu_income:[
    {'label':'1 - Less than $10,000', 'value':1}, 
    {'label':'2 - Less than $15,000 ($10,000 to less than $15,000)', 'value':2},
    {'label':'3 - Less than $20,000 ($15,000 to less than $20,000)', 'value':3},
    {'label':'4 - Less than $25,000 ($20,000 to less than $25,000)', 'value':4},
    {'label':'5 - Less than $35,000 ($25,000 to less than $35,000)', 'value':5},
    {'label':'6 - Less than $50,000 ($35,000 to less than $50,000)', 'value':6},
    {'label':'7 - Less than $75,000 ($50,000 to less than $75,000)', 'value':7},
    {'label':'8 - $75,000 or more', 'value':8}
    ]
     
user_input =    html.Div([
        dcc.Dropdown(
            id='menu_income',
            options=options,
            placeholder="Please choose your income range."
            #value='NYC1'  # Initial value
        ),
        dcc.Dropdown(
            id='my-dropdown2',
            options=options,
            placeholder="Select a city"
            #value='NYC2'  # Initial value
        ),
        dcc.Dropdown(
            id='my-dropdown3',
            options=options,
            placeholder="Select a city"
            #value='NYC3'  # Initial value
        )        
        
    ])

#layout = html.Div([title, user_input,  summary_table])

layout = html.Div([link, banner_item,user_input])



app = dash.Dash(__name__)  # Initialize Dash app
app.layout = layout        #set layout
#app.run_server(mode='inline', height=100)  # Run the server
app.run_server(mode='inline', height=100, port=8054)  # Change the port number (e.g., 8051)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8054/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
