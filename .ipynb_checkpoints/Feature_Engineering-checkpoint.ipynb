# %%
# CDC_Capstone:  Part III - Feature Engineering

# %%
#### Run imports:
# standard data science imports
import numpy as np
import pandas as pd
import seaborn as sns
#import matplotlib.pyplot as plt

 
# Statistics imports
#from scipy import stats
#import statsmodels.api as sm

import csv
#import import_ipynb
import pandas as pd

# %%
#save functions and data source
# %run my_functions.ipynb

# %% [markdown]
#
# # Why?  reading from your local directory  is much faster
# #run will do the follow:
#
# 1. take a list of names. For example: ['menhealth','menhealth','physical','dietary,heart','sex,edu','all']
# 2. each name will call another function to read the local directory and retrieve the CSV adn return it as a df
# note the directory name is defined in the run function found in my_functions file
# 3.  The data frame key will be the name.  Key, data will be the dataframe
# 4. The dictiionary of dataframes will be returned.

# %%
#read in all the data from your local directory.
data = run()

# %%
#Each dictionary keys include a sample subset of data with a total of 500 records with the exception of all.  All includes all the records.  They include 'menhealth','menhealth','physical','dietary','heart','sex','edu','all' 
#confirm 1 dictionary key 
data['menhealth']
# Out:
#      Diabetes_binary  MentHlth  Sex
# 0                  0         0    0
# 1                  1         4    0
# 2                  1         7    0
# 3                  0         2    0
# 4                  0        30    1
# ..               ...       ...  ...
# 495                0         0    0
# 496                1         0    1
# 497                0         0    0
# 498                0         5    1
# 499                0         0    0
#
# [500 rows x 3 columns]

# %% [markdown]
# # My New Naming Convention

# %% [markdown]
# ## `people`

# %%
#need to convert the dictionary ["all"]  to a dataframe.  remeber, all is the key
people = data['all']
people.head(2)
# Out:
#    ID  Diabetes_binary  HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 0   0                0       1         1          1   40       1       0
# 1   1                0       0         0          0   25       1       0
#
#    HeartDiseaseorAttack  PhysActivity  ...  AnyHealthcare  NoDocbcCost  \
# 0                     0             0  ...              1            0
# 1                     0             1  ...              0            1
#
#    GenHlth  MentHlth  PhysHlth  DiffWalk  Sex  Age  Education  Income
# 0        5        18        15         1    0    9          4       3
# 1        3         0         0         0    0    7          6       1
#
# [2 rows x 23 columns]

# %% [markdown]
# I  will use the name `people` to refer to the separate gender groups of people in our data.
#
# ### gender:
# * `"men"` - represents all data for men - where sex == 1
# * `"women"` - represents all data for women  - where sex == 2

# %%
#Obervation
# 0 - Male
# 1- Female

people.groupby(by = ['Sex']).count()[['Diabetes_binary']]
# Out:
#      Diabetes_binary
# Sex
# 0             141974
# 1             111706

# %%
#Using np.where for Conditional Replacement
#NumPy's where function can also be used for conditional replacements:
# Replace values in 'Sex'  with 'men' where the value is 0.  other will be women
people['Gender'] = np.where(people['Sex'] ==0, 'men', 'women')
people.head()
# Out:
#    ID  Diabetes_binary  HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 0   0                0       1         1          1   40       1       0
# 1   1                0       0         0          0   25       1       0
# 2   2                0       1         1          1   28       0       0
# 3   3                0       1         0          1   27       0       0
# 4   4                0       1         1          1   24       0       0
#
#    HeartDiseaseorAttack  PhysActivity  ...  NoDocbcCost  GenHlth  MentHlth  \
# 0                     0             0  ...            0        5        18
# 1                     0             1  ...            1        3         0
# 2                     0             0  ...            1        5        30
# 3                     0             1  ...            0        2         0
# 4                     0             1  ...            0        2         3
#
#    PhysHlth  DiffWalk  Sex  Age  Education  Income  Gender
# ...

# %% [markdown]
# ### `Types`
#
# We will use the name `kind` to refer to the two different kinds of people.
#
# * `"diabetics"`
# * `"nondiabetics"`

# %%
# Replace the value 2 in column 'column1' with 5
people['Type'] = np.where(people['Diabetes_binary'] ==0, 'nondiabetic', 'diabetic')

# %%
#Obervation
# 0 - nondiabetic
# 1- diabetic

people.groupby(by = ['Type']).count()[['Diabetes_binary']]
# Out:
#              Diabetes_binary
# Type
# diabetic               35346
# nondiabetic           218334

# %% [markdown]
# ### Add Labels to represent General Health

# %%
#definitions variable will be used in RFC table below to view cm matrix results
#1 Excellent
#2 Very good
#3 Good
#4 Fair
#5 Poor
#7 Don’t know/Not Sure 9 Refused
 
definitions = pd.Series([0, "Excellent", "Very good", "Good", "Fair","Poor","UNKNOWN"], dtype="category")

# %%
reversefactor = dict(zip(range(7),definitions))
reversefactor
# Out:
# {0: 0,
#  1: 'Excellent',
#  2: 'Very good',
#  3: 'Good',
#  4: 'Fair',
#  5: 'Poor',
#  6: 'UNKNOWN'}

# %%
people['GeneralHealth'] = np.vectorize(reversefactor.get)(people[['GenHlth']])
#y_pred_v = np.vectorize(reversefactor.get)(y_pred)

# %%
people.columns
# Out:
# Index(['ID', 'Diabetes_binary', 'HighBP', 'HighChol', 'CholCheck', 'BMI',
#        'Smoker', 'Stroke', 'HeartDiseaseorAttack', 'PhysActivity', 'Fruits',
#        'Veggies', 'HvyAlcoholConsump', 'AnyHealthcare', 'NoDocbcCost',
#        'GenHlth', 'MentHlth', 'PhysHlth', 'DiffWalk', 'Sex', 'Age',
#        'Education', 'Income', 'Gender', 'Types', 'GeneralHealth'],
#       dtype='object')

# %%
#convert back to dataframe
people.head()
# Out:
#    ID  Diabetes_binary  HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 0   0                0       1         1          1   40       1       0
# 1   1                0       0         0          0   25       1       0
# 2   2                0       1         1          1   28       0       0
# 3   3                0       1         0          1   27       0       0
# 4   4                0       1         1          1   24       0       0
#
#    HeartDiseaseorAttack  PhysActivity  ...  MentHlth  PhysHlth  DiffWalk  Sex  \
# 0                     0             0  ...        18        15         1    0
# 1                     0             1  ...         0         0         0    0
# 2                     0             0  ...        30        30         1    0
# 3                     0             1  ...         0         0         0    0
# 4                     0             1  ...         3         0         0    0
#
# ...

# %%
#Verified counts are the same

df_gen_h = people.groupby(by = ['GeneralHealth','GenHlth']).count()[['Diabetes_binary']]
df_gen_h
# Out:
#                        Diabetes_binary
# GeneralHealth GenHlth
# Excellent     1                  45299
# Fair          4                  31570
# Good          3                  75646
# Poor          5                  12081
# Very good     2                  89084

# %% [markdown]
# Question: How many people with good health have diabetis compared to others? 75646

# %%
#1 filter only People with Diabetis 1 - True
#2 filter only people w/o Diabetis  0 = False No diabetis
#3 Create Bar Chart

# %%
filter_has_Diabetis  = people['Type'] == 'diabetic'

# %%
df_diabetes = people[filter_has_Diabetis]

# %%
df_diabetes.head(1)
# Out:
#    ID  Diabetes_binary  HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 8   8                1       1         1          1   30       1       0
#
#    HeartDiseaseorAttack  PhysActivity  ...  PhysHlth  DiffWalk  Sex  Age  \
# 8                     1             0  ...        30         1    0    9
#
#    Education  Income  Gender      Types  GeneralHealth      Type
# 8          5       1     men  diabetics           Poor  diabetic
#
# [1 rows x 27 columns]

# %%
#now filter good health
filter_good_health = df_diabetes["GeneralHealth"] == 'Good'

# %%
df_Diabetis_goodHealth  = df_diabetes[filter_good_health]

# %%
df_Diabetis_goodHealth.head()
# Out:
#     ID  Diabetes_binary  HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 10  10                1       0         0          1   25       1       0
# 41  41                1       1         0          1   31       0       0
# 49  49                1       1         1          1   33       1       0
# 60  60                1       1         0          1   27       0       0
# 68  68                1       1         0          1   21       1       0
#
#     HeartDiseaseorAttack  PhysActivity  ...  PhysHlth  DiffWalk  Sex  Age  \
# 10                     0             1  ...         0         0    1   13
# 41                     0             0  ...         5         0    0   13
# 49                     0             0  ...        30         1    0   11
# 60                     0             1  ...         0         0    0   11
# 68                     0             1  ...         0         1    0   10
#
#     Education  Income  Gender      Types  GeneralHealth      Type
# ...

# %%
GenHe_has_Diabetis_df = has_Diabetis_df.groupby('GenHealth', as_index=False).agg('count')
GenHe_has_Diabetis_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 GenHe_has_Diabetis_df = has_Diabetis_df.groupby('GenHealth', as_index=False).agg('count')
#       2 GenHe_has_Diabetis_df.head()
#
# NameError: name 'has_Diabetis_df' is not defined

# %%
sns.barplot(y='Diabetes_binary', x='GenHealth',data=GenHe_has_Diabetis_df)
 
# Add a title
plt.title("Diabetes Diagnosis = Yes")

plt.show()

# %% [markdown]
# Individuals in good health can still get diabetes

# %%
df_concat_grp.columns
# Out:
# Index(['GenHealth', 'GenHlth', 'ID', 'Diabetes_binary', 'HighBP', 'HighChol',
#        'CholCheck', 'BMI', 'Smoker', 'Stroke', 'HeartDiseaseorAttack',
#        'PhysActivity', 'Fruits', 'Veggies', 'HvyAlcoholConsump',
#        'AnyHealthcare', 'NoDocbcCost', 'MentHlth', 'PhysHlth', 'DiffWalk',
#        'Sex', 'Age', 'Education', 'Income'],
#       dtype='object')

# %%
#1 filter only People with Diabetis 1 - True
#2 filter only people w/o Diabetis  0 = False No diabetis
#3 Create Bar Chart
hasNo_Diabetis = df_concat['Diabetes_binary'] == 0

# %%
hasNo_Diabetis_df = df_concat[hasNo_Diabetis]

# %%
hasNo_Diabetis_df.head()
# Out:
#    ID  Diabetes_binary  HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 0   0                0       1         1          1   40       1       0
# 1   1                0       0         0          0   25       1       0
# 2   2                0       1         1          1   28       0       0
# 3   3                0       1         0          1   27       0       0
# 4   4                0       1         1          1   24       0       0
#
#    HeartDiseaseorAttack  PhysActivity  ...  NoDocbcCost  GenHlth  MentHlth  \
# 0                     0             0  ...            0        5        18
# 1                     0             1  ...            1        3         0
# 2                     0             0  ...            1        5        30
# 3                     0             1  ...            0        2         0
# 4                     0             1  ...            0        2         3
#
#    PhysHlth  DiffWalk  Sex  Age  Education  Income  GenHealth
# ...

# %%
GenHe_hasNo_Diabetis_df = hasNo_Diabetis_df.groupby('GenHealth', as_index=False).agg('count')
GenHe_hasNo_Diabetis_df.head()
# Out:
#    GenHealth     ID  Diabetes_binary  HighBP  HighChol  CholCheck    BMI  \
# 0  Excellent  44159            44159   44159     44159      44159  44159
# 1       Fair  21780            21780   21780     21780      21780  21780
# 2       Good  62189            62189   62189     62189      62189  62189
# 3       Poor   7503             7503    7503      7503       7503   7503
# 4  Very good  82703            82703   82703     82703      82703  82703
#
#    Smoker  Stroke  HeartDiseaseorAttack  ...  AnyHealthcare  NoDocbcCost  \
# 0   44159   44159                 44159  ...          44159        44159
# 1   21780   21780                 21780  ...          21780        21780
# 2   62189   62189                 62189  ...          62189        62189
# 3    7503    7503                  7503  ...           7503         7503
# 4   82703   82703                 82703  ...          82703        82703
#
#    GenHlth  MentHlth  PhysHlth  DiffWalk    Sex    Age  Education  Income
# ...

# %%
sns.barplot(y='Diabetes_binary', x='GenHealth',data=GenHe_hasNo_Diabetis_df)
 
# Add a title
plt.title("Diabetes Diagnosis = No")

plt.show()

# %% [markdown]
# People that are in very good health do not have diabets

# %% [markdown]
# ### Feature Engineer Labels for Income

# %%
#definitions variable will be used in RFC table below to view cm matrix results

 
definitions = pd.Series([0, "<10K", "10-15K", "15-20K", "20-25K","25K-35K","35-50K","50-75K","75>"], dtype="category")

# %%
reversefactor = dict(zip(range(7),definitions))
reversefactor
# Out:
# {0: 0,
#  1: '<10K',
#  2: '10-15K',
#  3: '15-20K',
#  4: '20-25K',
#  5: '25K-35K',
#  6: '35-50K'}

# %%
new_df = np.vectorize(reversefactor.get)(df[['Income']])

# %%
print(new_df[:5])
# Out:
# [['15-20K']
#  ['<10K']
#  ['None']
#  ['35-50K']
#  ['20-25K']]

# %%
#Add new def to df
print(type(new_df))
# Out:
# <class 'numpy.ndarray'>

# %%
# Convert to DataFrame
df_income_label = pd.DataFrame(new_df, columns=['income']).reindex()

# %%
df_income_label.head(2)
# Out:
#    income
# 0  15-20K
# 1    <10K

# %%
#Merge 2 dataframes
# Merge DataFrames based on the 'key' column
df_concat = pd.concat([df,df_income_label], axis=1)

# %%
df_concat.head()
# Out:
#    ID  Diabetes_binary  HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 0   0                0       1         1          1   40       1       0
# 1   1                0       0         0          0   25       1       0
# 2   2                0       1         1          1   28       0       0
# 3   3                0       1         0          1   27       0       0
# 4   4                0       1         1          1   24       0       0
#
#    HeartDiseaseorAttack  PhysActivity  ...  NoDocbcCost  GenHlth  MentHlth  \
# 0                     0             0  ...            0        5        18
# 1                     0             1  ...            1        3         0
# 2                     0             0  ...            1        5        30
# 3                     0             1  ...            0        2         0
# 4                     0             1  ...            0        2         3
#
#    PhysHlth  DiffWalk  Sex  Age  Education  Income  income
# ...

# %%
df_concat[[ 'Income','income','GenHlth','Diabetes_binary','HighBP','HighChol']].head()
# Out:
#    Income  income  GenHlth  Diabetes_binary  HighBP  HighChol
# 0       3  15-20K        5                0       1         1
# 1       1    <10K        3                0       0         0
# 2       8    None        5                0       1         1
# 3       6  35-50K        2                0       1         0
# 4       4  20-25K        2                0       1         1

# %% [markdown]
# Question: How many people with good health have diabetis compared to others
# ?

# %%
#1 filter only People with Diabetis 1 - True
#2 filter only people w/o Diabetis  0 = False No diabetis
#3 Create Bar Chart
has_Diabetis = df_concat['Diabetes_binary'] == 1

# %%
has_Diabetis_df = df_concat[has_Diabetis]

# %%
has_Diabetis_df.head()
# Out:
#     ID  Diabetes_binary  HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 8    8                1       1         1          1   30       1       0
# 10  10                1       0         0          1   25       1       0
# 13  13                1       1         1          1   28       0       0
# 17  17                1       0         0          1   23       1       0
# 23  23                1       1         0          1   27       0       0
#
#     HeartDiseaseorAttack  PhysActivity  ...  NoDocbcCost  GenHlth  MentHlth  \
# 8                      1             0  ...            0        5        30
# 10                     0             1  ...            0        3         0
# 13                     0             0  ...            0        4         0
# 17                     0             1  ...            0        2         0
# 23                     0             1  ...            0        1         0
#
#     PhysHlth  DiffWalk  Sex  Age  Education  Income  income
# ...

# %%
income_has_Diabetis_df = has_Diabetis_df.groupby('income', as_index=False).agg('count')
income_has_Diabetis_df.head()
# Out:
#     income    ID  Diabetes_binary  HighBP  HighChol  CholCheck   BMI  Smoker  \
# 0   10-15K  3086             3086    3086      3086       3086  3086    3086
# 1   15-20K  3568             3568    3568      3568       3568  3568    3568
# 2   20-25K  4054             4054    4054      4054       4054  4054    4054
# 3  25K-35K  4504             4504    4504      4504       4504  4504    4504
# 4   35-50K  5291             5291    5291      5291       5291  5291    5291
#
#    Stroke  HeartDiseaseorAttack  ...  AnyHealthcare  NoDocbcCost  GenHlth  \
# 0    3086                  3086  ...           3086         3086     3086
# 1    3568                  3568  ...           3568         3568     3568
# 2    4054                  4054  ...           4054         4054     4054
# 3    4504                  4504  ...           4504         4504     4504
# 4    5291                  5291  ...           5291         5291     5291
#
# ...

# %%
sns.barplot(y='Diabetes_binary', x='income',data=income_has_Diabetis_df)
 
# Add a title
plt.title("Diabetes Diagnosis = Yes")

plt.show()

# %% [markdown]
# People in the income range of 35-50K have been diagnosed with diabetis cases

# %%
df_concat_grp.columns
# Out:
# Index(['GenHealth', 'GenHlth', 'ID', 'Diabetes_binary', 'HighBP', 'HighChol',
#        'CholCheck', 'BMI', 'Smoker', 'Stroke', 'HeartDiseaseorAttack',
#        'PhysActivity', 'Fruits', 'Veggies', 'HvyAlcoholConsump',
#        'AnyHealthcare', 'NoDocbcCost', 'MentHlth', 'PhysHlth', 'DiffWalk',
#        'Sex', 'Age', 'Education', 'Income'],
#       dtype='object')

# %%
#1 filter only People with Diabetis 1 - True
#2 filter only people w/o Diabetis  0 = False No diabetis
#3 Create Bar Chart
hasNo_Diabetis = df_concat['Diabetes_binary'] == 0

# %%
hasNo_Diabetis_df = df_concat[hasNo_Diabetis]

# %%
hasNo_Diabetis_df.head()
# Out:
#    ID  Diabetes_binary  HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 0   0                0       1         1          1   40       1       0
# 1   1                0       0         0          0   25       1       0
# 2   2                0       1         1          1   28       0       0
# 3   3                0       1         0          1   27       0       0
# 4   4                0       1         1          1   24       0       0
#
#    HeartDiseaseorAttack  PhysActivity  ...  NoDocbcCost  GenHlth  MentHlth  \
# 0                     0             0  ...            0        5        18
# 1                     0             1  ...            1        3         0
# 2                     0             0  ...            1        5        30
# 3                     0             1  ...            0        2         0
# 4                     0             1  ...            0        2         3
#
#    PhysHlth  DiffWalk  Sex  Age  Education  Income  income
# ...

# %%
income_hasNo_Diabetis_df = hasNo_Diabetis_df.groupby('income', as_index=False).agg('count')
income_hasNo_Diabetis_df.head()
# Out:
#     income     ID  Diabetes_binary  HighBP  HighChol  CholCheck    BMI  \
# 0   10-15K   8697             8697    8697      8697       8697   8697
# 1   15-20K  12426            12426   12426     12426      12426  12426
# 2   20-25K  16081            16081   16081     16081      16081  16081
# 3  25K-35K  21379            21379   21379     21379      21379  21379
# 4   35-50K  31179            31179   31179     31179      31179  31179
#
#    Smoker  Stroke  HeartDiseaseorAttack  ...  AnyHealthcare  NoDocbcCost  \
# 0    8697    8697                  8697  ...           8697         8697
# 1   12426   12426                 12426  ...          12426        12426
# 2   16081   16081                 16081  ...          16081        16081
# 3   21379   21379                 21379  ...          21379        21379
# 4   31179   31179                 31179  ...          31179        31179
#
#    GenHlth  MentHlth  PhysHlth  DiffWalk    Sex    Age  Education  Income
# ...

# %%
sns.barplot(y='Diabetes_binary', x='income',data=income_hasNo_Diabetis_df)
 
# Add a title
plt.title("Diabetes Diagnosis = No")

plt.show()

# %% [markdown]
# Indiduals that make less than 10K are less likely to get diabetes when compared to other income ranges

# %%
income_has_Diabetis_df

# %% [markdown]
# ### Feature Engineer Labels for Education

# %%
#PhysHlth  DiffWalk  Sex  Age  Education  Income  
#1 Never attended school or only kindergarten  
#2 Grades 1 through 8 (Elementary)   
#3 Grades 9 through 11 (Some high school)   
#4 Grade 12 or GED (High school graduate)   
#5 College 1 year to 3 years (Some college or technical school)   
#6 College 4 years or more (College graduate)   
#9 Refused   
#BLANK Not asked or Missing 1,770

# %%
#definitions variable will be used in RFC table below to view cm matrix results

 
definitions = pd.Series([0, "None", "1-8", "9-11", "12orGED","C1-3","C4+"], dtype="category")

# %%
reversefactor = dict(zip(range(7),definitions))
reversefactor
# Out:
# {0: 0, 1: 'None', 2: '1-8', 3: '9-11', 4: '12orGED', 5: 'C1-3', 6: 'C4+'}

# %%
new_df = np.vectorize(reversefactor.get)(df[['Education']])

# %%
print(new_df[:5])
# Out:
# [['12orGED']
#  ['C4+']
#  ['12orGED']
#  ['9-11']
#  ['C1-3']]

# %%
#Add new def to df
print(type(new_df))
# Out:
# <class 'numpy.ndarray'>

# %%
# Convert to DataFrame
df_education_label = pd.DataFrame(new_df, columns=['education']).reindex()

# %%
df_education_label.head(2)
# Out:
#   education
# 0   12orGED
# 1       C4+

# %%
#Merge 2 dataframes
# Merge DataFrames based on the 'key' column
df_concat = pd.concat([df,df_education_label], axis=1)

# %%
df_concat.head()
# Out:
#    ID  Diabetes_binary  HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 0   0                0       1         1          1   40       1       0
# 1   1                0       0         0          0   25       1       0
# 2   2                0       1         1          1   28       0       0
# 3   3                0       1         0          1   27       0       0
# 4   4                0       1         1          1   24       0       0
#
#    HeartDiseaseorAttack  PhysActivity  ...  NoDocbcCost  GenHlth  MentHlth  \
# 0                     0             0  ...            0        5        18
# 1                     0             1  ...            1        3         0
# 2                     0             0  ...            1        5        30
# 3                     0             1  ...            0        2         0
# 4                     0             1  ...            0        2         3
#
#    PhysHlth  DiffWalk  Sex  Age  Education  Income  education
# ...

# %%
df_concat[[ 'Education','education','GenHlth','Diabetes_binary','HighBP','HighChol']].head()
# Out:
#    Education education  GenHlth  Diabetes_binary  HighBP  HighChol
# 0          4   12orGED        5                0       1         1
# 1          6       C4+        3                0       0         0
# 2          4   12orGED        5                0       1         1
# 3          3      9-11        2                0       1         0
# 4          5      C1-3        2                0       1         1

# %% [markdown]
# Question: How many people with higher education have diabetis compared to others
# ?

# %%
#1 filter only People with Diabetis 1 - True
#2 filter only people w/o Diabetis  0 = False No diabetis
#3 Create Bar Chart
has_Diabetis = df_concat['Diabetes_binary'] == 1

# %%
has_Diabetis_df = df_concat[has_Diabetis]

# %%
has_Diabetis_df.head()
# Out:
#     ID  Diabetes_binary  HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 8    8                1       1         1          1   30       1       0
# 10  10                1       0         0          1   25       1       0
# 13  13                1       1         1          1   28       0       0
# 17  17                1       0         0          1   23       1       0
# 23  23                1       1         0          1   27       0       0
#
#     HeartDiseaseorAttack  PhysActivity  ...  NoDocbcCost  GenHlth  MentHlth  \
# 8                      1             0  ...            0        5        30
# 10                     0             1  ...            0        3         0
# 13                     0             0  ...            0        4         0
# 17                     0             1  ...            0        2         0
# 23                     0             1  ...            0        1         0
#
#     PhysHlth  DiffWalk  Sex  Age  Education  Income  education
# ...

# %%
edu_has_Diabetis_df = has_Diabetis_df.groupby('education', as_index=False).agg('count')
edu_has_Diabetis_df.head()
# Out:
#   education     ID  Diabetes_binary  HighBP  HighChol  CholCheck    BMI  \
# 0       1-8   1183             1183    1183      1183       1183   1183
# 1   12orGED  11066            11066   11066     11066      11066  11066
# 2      9-11   2296             2296    2296      2296       2296   2296
# 3      C1-3  10354            10354   10354     10354      10354  10354
# 4       C4+  10400            10400   10400     10400      10400  10400
#
#    Smoker  Stroke  HeartDiseaseorAttack  ...  AnyHealthcare  NoDocbcCost  \
# 0    1183    1183                  1183  ...           1183         1183
# 1   11066   11066                 11066  ...          11066        11066
# 2    2296    2296                  2296  ...           2296         2296
# 3   10354   10354                 10354  ...          10354        10354
# 4   10400   10400                 10400  ...          10400        10400
#
#    GenHlth  MentHlth  PhysHlth  DiffWalk    Sex    Age  Education  Income
# ...

# %%
sns.barplot(y='Diabetes_binary', x='education',data=edu_has_Diabetis_df)
 
# Add a title
plt.title("Diabetes Diagnosis = Yes")

plt.show()

# %% [markdown]
# People with education level 12 or GED is slighter more to be diagnosedthat someone with college education

# %%
#1 filter only People with Diabetis 1 - True
#2 filter only people w/o Diabetis  0 = False No diabetis
#3 Create Bar Chart
hasNo_Diabetis = df_concat['Diabetes_binary'] == 0

# %%
hasNo_Diabetis_df = df_concat[hasNo_Diabetis]

# %%
hasNo_Diabetis_df.head()
# Out:
#    ID  Diabetes_binary  HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 0   0                0       1         1          1   40       1       0
# 1   1                0       0         0          0   25       1       0
# 2   2                0       1         1          1   28       0       0
# 3   3                0       1         0          1   27       0       0
# 4   4                0       1         1          1   24       0       0
#
#    HeartDiseaseorAttack  PhysActivity  ...  NoDocbcCost  GenHlth  MentHlth  \
# 0                     0             0  ...            0        5        18
# 1                     0             1  ...            1        3         0
# 2                     0             0  ...            1        5        30
# 3                     0             1  ...            0        2         0
# 4                     0             1  ...            0        2         3
#
#    PhysHlth  DiffWalk  Sex  Age  Education  Income  education
# ...

# %%
edu_hasNo_Diabetis_df = hasNo_Diabetis_df.groupby('education', as_index=False).agg('count')
edu_hasNo_Diabetis_df.head()
# Out:
#   education     ID  Diabetes_binary  HighBP  HighChol  CholCheck    BMI  \
# 0       1-8   2860             2860    2860      2860       2860   2860
# 1   12orGED  51684            51684   51684     51684      51684  51684
# 2      9-11   7182             7182    7182      7182       7182   7182
# 3      C1-3  59556            59556   59556     59556      59556  59556
# 4       C4+  96925            96925   96925     96925      96925  96925
#
#    Smoker  Stroke  HeartDiseaseorAttack  ...  AnyHealthcare  NoDocbcCost  \
# 0    2860    2860                  2860  ...           2860         2860
# 1   51684   51684                 51684  ...          51684        51684
# 2    7182    7182                  7182  ...           7182         7182
# 3   59556   59556                 59556  ...          59556        59556
# 4   96925   96925                 96925  ...          96925        96925
#
#    GenHlth  MentHlth  PhysHlth  DiffWalk    Sex    Age  Education  Income
# ...

# %%
sns.barplot(y='Diabetes_binary', x='education',data=edu_hasNo_Diabetis_df)
 
# Add a title
plt.title("Diabetes Diagnosis = No")

plt.show()

# %% [markdown]
# There are more individuals without diabetes than any other eduction level

# %% [markdown]
# ### Export Data for dashboard¶

# %%
def write_data(data, directory, **kwargs):
    for name, df in data.items():
        df.to_csv(f"{directory}/{name}.csv", **kwargs)

# %%
#Export dataframe to CSV
GenHe_hasNo_Diabetis_df.to_csv('data/prepared/GenHe_hasNo_Diabetis_data.csv',index=False)

GenHe_has_Diabetis_df.to_csv('data/prepared/GenHe_has_Diabetis_data.csv',index=False)

income_hasNo_Diabetis_df.to_csv('data/prepared/income_hasNo_Diabetis_data.csv',index=False)

income_has_Diabetis_df.to_csv('data/prepared/income_has_Diabetis.csv',index=False)

edu_has_Diabetis_df.to_csv('data/prepared/edu_has_Diabetis_data.csv',index=False)
edu_hasNo_Diabetis_df.to_csv('data/prepared/edu_hasNo_Diabetis_data.csv',index=False)
